# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiMejia/ML-Projects/blob/main/Potential_Talents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <b> Potential Candidates  - Predicting the best fit</b>
# <a id='top'></a>

# %% [markdown]
# #### <b> Table of Contents</b>

# %% [markdown]
# 1.  <a href="#Context">Context</a>
# 2.  <a href="#Data">Data</a>
# 1.  <a href="#Text Cleaning">Text Cleaning</a>
# 1. <a href="#Text Preprocessing">Text Preprocessing</a>
# 1. <a href="#Text Representation (Text Vectorization)">Text Representation (Text Vectorization)</a>
#     <br><a href="#Traditional Approach: Term-Frequency-Inverse Document Frequency (TF-IDF)"> Traditional Approach: Term-Frequency-Inverse Document Frequency (TF-IDF)</a><br>
#     <a href="#Keyword based search: Seeking Human Resources"> i) Keyword
# based search: Seeking Human Resources</a> <br>
#     <a href="#Keyword based search: Aspiring Human Resources">ii) Keyword based search: Aspiring Human Resources</a><br>
#     <a href="#Keyword based search: Research Assistant">iii) Keyword based search: Research Assistant</a><br>
#   <a href="#Final Notes">Final Notes</a>

# %% [markdown]
# <a name="Context"></a>
# #### <b> 1. Context</b>

# %% [markdown]
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">
# A talent sourcing and management company is interested in finding good candidates for tech companies. So they can outsource those candidates. However, finding a good fit for opening positions is not an easy task. This is because the firm faces three key challenges:  <br>
# 1) Getting a deep understanding of the position, <br>
# 2) Defining the skillset candidates must have to be selected, and  <br>
# 3) Contacting the best job seekers.
#
# As this job requires a lot of labourios work, an automate process could be benefitial for the company while connecting with top performers workers more efficiently.<br>
#
# **Goal:** Predict how fit the candidate is based on their available information (variable fit).<br>
#
# <b>Data</b> <br>
# The data comes from our sourcing efforts. Contains an unique identifier for each candidate to ensure the company is compliant with data privacy laws. <br>
#
# <b>Attributes</b>  <br>
# **id:** unique identifier for candidate (numeric) <br>
# **job_title:** job title for candidate (text) <br>
# **location:** geographical location for candidate (text) <br>
# **connections** number of connections candidate has, 500+ means over 500 (text) <br>
#
# **Output (desired target):** <br>
# **fit** - how fit the candidate is for the role? (numeric, probability between 0-1)  <br>
# **Keywords** - “Aspiring human resources” or “seeking human resources”
# </p>

# %%
#Installing libraries
# %pip install nltk pyspark wordfreq gensim
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: wordfreq in /usr/local/lib/python3.11/dist-packages (3.1.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: ftfy>=6.1 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (6.3.1)
# Requirement already satisfied: langcodes>=3.0 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (3.5.0)
# Requirement already satisfied: locate<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (1.1.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (1.1.1)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy>=6.1->wordfreq) (0.2.13)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes>=3.0->wordfreq) (1.3.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes>=3.0->wordfreq) (1.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from marisa-trie>=1.1.0->language-data>=1.2->langcodes>=3.0->wordfreq) (75.2.0)

# %% [markdown]
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">
# <b>Importing Libraries</b> </p>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Model building libraries
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('words')
import gensim
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.corpus import words
from wordfreq import word_frequency
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
import spacy
from spacy import displacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# <a name="Data"></a>
# #### <b>2. Data</b>
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">Loading and previewing the raw data to understand its structure.</p>

# %%
### Open the csv file

# Alternatively, you can open the file using the url + file id
data = pd.read_csv("https://drive.google.com/uc?id=13p6JXZUvAdXccUOMSMHRo2qsko0hLlr3", on_bad_lines='skip', engine='python', index_col=0)
pd.set_option('display.max_colwidth', 200)                                      # set_option allows to expand the column's width to see the full text

data = data.iloc[:,:3]                                                          # Removing the fit column because it doesn't add any value
data.head()
# Out:
#                                                                                                    job_title  \
# id
# 1   2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 2                                                  Native English Teacher at EPIK (English Program in Korea)
# 3                                                                      Aspiring Human Resources Professional
# 4                                                                     People Development Coordinator at Ryan
# 5                                                            Advisory Board Member at Celal Bayar University
#
#                                location connection
# id
# 1                        Houston, Texas         85
# 2                                Kanada      500+
# 3   Raleigh-Durham, North Carolina Area         44
# 4                         Denton, Texas      500+
# 5                        İzmir, Türkiye      500+

# %%
# This is a small dataset
data.shape
# Out:
# (104, 3)

# %% [markdown]
# <a name="Text Cleaning"></a>
# #### <b>3. Text Cleaning</b>
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">Cleaning the text data.</p>

# %%
import re

abbv_map = {'c': 'charles','epik': 'english program korea','hr': 'human resources','hris': 'human resources information system','svp': 'senior vice president',
               'chro': 'chief human resources officer','csr': 'corporate social responsibility officer','engie': 'energy company','gphr': 'global professional human resources',
               'sphr': 'senior professional human resources','inc': 'company','mes': 'manufacturing execution system','heil': 'environmental company','gi': 'geographic information system',
               'rrp': 'recommended retail price','jti': 'japan tobacco international','ey': 'ernst young ','lab': 'laboratory','st': 'saint'}

def expand_abbv(text):
  if pd.isnull(text):
    return text
  else:
    sorted_keys = sorted(abbv_map.keys(), key=len, reverse=True)              # Sort keys by length to avoid partial replacements (e.g., 'hr' inside 'hris')
    for key in sorted_keys:
        pattern = r'\b' + re.escape(key) + r'\b'                               # Use word boundaries to match whole words only
        text = re.sub(pattern, abbv_map[key], text, flags=re.IGNORECASE)
    return text

text = data['job_title'].apply(expand_abbv)
text.head(10)
# Out:
# id
# 1     2019 charles.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 2                                         Native English Teacher at english program korea (English Program in Korea)
# 3                                                                              Aspiring Human Resources Professional
# 4                                                                             People Development Coordinator at Ryan
# 5                                                                    Advisory Board Member at Celal Bayar University
# 6                                                                                Aspiring Human Resources Specialist
# 7                                                  Student at Humber College and Aspiring Human Resources Generalist
# 8                                                                                  human resources Senior Specialist
# 9                                                  Student at Humber College and Aspiring Human Resources Generalist
# 10                               Seeking Human Resources human resources information system and Generalist Positions
# Name: job_title, dtype: object

# %% [markdown]
# <a name="Text Preprocessing"></a>
# #### <b>4. Text Preprocessing</b>
# <p> This step requires to clean, transform, and prepare the text for analysis and modeling.<br>
# <b>Key techiques:</b> Tokenization, Stopwords, Stemming, and Lemmatization. </p>

# %%
def text_preprocessing(text):
  '''
  Function to clean the text, transform and prepare it for analysis and modeling.
  '''

  # Tokenization & lowercasing
  tokenizer = RegexpTokenizer(r'\w+')
  stop_words = set(word.lower() for word in nltk.corpus.stopwords.words('english'))
  lemmatizer = WordNetLemmatizer()

  # If passing a string
  if isinstance(text, str):
    text =tokenizer.tokenize(text.lower())
    text = [word for word in text if word not in stop_words and not word.isdigit()]
    text = [lemmatizer.lemmatize(word, pos=wordnet.VERB) for word in text]

    return ' '.join(text)

  # If passing a series
  else:
    text = (text.str.lower()).apply(tokenizer.tokenize)                                # The text is divided into individuals words (tokens)
    text = text.apply(lambda tokens:[
      WordNetLemmatizer().lemmatize(word, pos=wordnet.VERB)
      for word in tokens
      if word not in stop_words and not word.isdigit()])                                 # This line removes stopwords and digits


  # join tokens into a single string
  joined_text = text.apply(lambda tokens:' '.join(tokens))

  return joined_text

# Applying the preprocessing function
text_prep = text_preprocessing(text)
text_prep.head(10)
# Out:
# id
# 1     charles bauer college business graduate magna cum laude aspire human resources professional
# 2                              native english teacher english program korea english program korea
# 3                                                             aspire human resources professional
# 4                                                             people development coordinator ryan
# 5                                                    advisory board member celal bayar university
# 6                                                               aspire human resources specialist
# 7                                        student humber college aspire human resources generalist
# 8                                                               human resources senior specialist
# 9                                        student humber college aspire human resources generalist
# 10                    seek human resources human resources information system generalist position
# Name: job_title, dtype: object

# %% [markdown]
# <a name="Text Representation (Text Vectorization)"></a>
# #### <b>5. Text Representation (Text Vectorization)</b>
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;"> This step helps us to transform the text into its numerical vector. So the ML algorithm  can ingests the text.</p>

# %% [markdown]
# <a name="Traditional Approach: Term-Frequency-Inverse Document Frequency (TF-IDF)"></a>
# <b>Traditional Approach: Term-Frequency-Inverse Document Frequency (TF-IDF)</b>

# %%
# Evaluating three ranking options
from sklearn.metrics.pairwise import cosine_similarity

def keyword_ranking(text,ngram_range, boost):
    # TF-IDF set up
    tfidf = TfidfVectorizer(ngram_range=ngram_range)                                        # Defining the n-grams also help to increase score and gain more precise results
    tfidf_vec = tfidf.fit_transform(text)

    # Keyword Input
    keyword = input("Enter a keyword: ")
    keyword_prep = text_preprocessing(keyword)
    query_vec = tfidf.transform([keyword_prep])

    cosine_ekw = cosine_similarity(query_vec, tfidf_vec).flatten()

    ### ------------ 3. Exact Keyword-based Ranking ----------- ####
    data['score'] = cosine_ekw
    data['score'] += (text.str.contains(keyword_prep)).astype(int) * boost         # This line allows direct string match
    data['ranks'] = data['score'].rank(method='dense', ascending=False).astype(int)

    pd.set_option('display.max_rows', None)
    df = data.sort_values(by='ranks')
    return df

# %% [markdown]
# <a name="Keyword based search: Seeking Human Resources"></a>
# <b>i) Keyword based search: Seeking Human Resources</b>

# %%
# Getting ranks for seeking human resources
shr = keyword_ranking(
    text=text_prep,
    ngram_range=(1, 3),
    boost=0.2
)
shr
# Out:
# Enter a keyword: seeking human resources
#                                                                                                                  job_title  \
# id
# 28                                                                                   Seeking Human Resources Opportunities
# 30                                                                                   Seeking Human Resources Opportunities
# 99                                                                                        Seeking Human Resources Position
# 62                                                                   Seeking Human Resources HRIS and Generalist Positions
# 40                                                                   Seeking Human Resources HRIS and Generalist Positions
# 53                                                                   Seeking Human Resources HRIS and Generalist Positions
# 10                                                                   Seeking Human Resources HRIS and Generalist Positions
# 94                                                  Seeking Human  Resources Opportunities. Open to travel and relocation.
# 75                    Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621
# 73                                                Aspiring Human Resources Manager, seeking internship in Human Resources.
# 74                                                                                            Human Resources Professional
# 27                                                       Aspiring Human Resources Management student seeking an internship
# 29                                                       Aspiring Human Resources Management student seeking an internship
# 33                                                                                   Aspiring Human Resources Professional
# 97                                                                                   Aspiring Human Resources Professional
# 46                                                                                   Aspiring Human Resources Professional
# 17                                                                                   Aspiring Human Resources Professional
# 58                                                                                   Aspiring Human Resources Professional
# 21                                                                                   Aspiring Human Resources Professional
# 3                                                                                    Aspiring Human Resources Professional
# 60                                                                                     Aspiring Human Resources Specialist
# 6                                                                                      Aspiring Human Resources Specialist
# 36                                                                                     Aspiring Human Resources Specialist
# 24                                                                                     Aspiring Human Resources Specialist
# 49                                                                                     Aspiring Human Resources Specialist
# 100  Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis
# 61                                                                                                    HR Senior Specialist
# 38                                                                                                    HR Senior Specialist
# 51                                                                                                    HR Senior Specialist
# 8                                                                                                     HR Senior Specialist
# 26                                                                                                    HR Senior Specialist
# 70                          Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.
# 78                                                                                  Human Resources Generalist at Schwan's
# 101                                                                                  Human Resources Generalist at Loparex
# 68                                                                                 Human Resources Specialist at Luxottica
# 88                                                                                        Human Resources Management Major
# 64             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 55             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 12             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 42             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 7                                                        Student at Humber College and Aspiring Human Resources Generalist
# 9                                                        Student at Humber College and Aspiring Human Resources Generalist
# 50                                                       Student at Humber College and Aspiring Human Resources Generalist
# 25                                                       Student at Humber College and Aspiring Human Resources Generalist
# 52                                                       Student at Humber College and Aspiring Human Resources Generalist
# 39                                                       Student at Humber College and Aspiring Human Resources Generalist
# 37                                                       Student at Humber College and Aspiring Human Resources Generalist
# 71                                                                         Human Resources Generalist at ScottMadden, Inc.
# 13                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 43                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 65                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 56                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 67                                                                   Human Resources, Staffing and Recruiting Professional
# 89                                                                                         Director Human Resources  at EY
# 92                                                Seeking employment opportunities within Customer Service or Patient Care
# 66                                                    Experienced Retail Manager and aspiring Human Resources Professional
# 72                                                          Business Management Major and Aspiring Human Resources Manager
# 79                                                                   Liberal Arts Major. Aspiring Human Resources Analyst.
# 84                                                       Human Resources professional for the world leader in GIS software
# 82                                            Aspiring Human Resources Professional | An energetic and Team-Focused Leader
# 83                                                                               HR Manager at Endemol Shine North America
# 1                 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 57                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 19                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 15                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 44                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 31                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 14                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 69                                                              Director of Human Resources North America, Groupe Beneteau
# 81                                                           Senior Human Resources Business Partner at Heil Environmental
# 76   Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment
# 77                 Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation
# 63                                                                                           Student at Chapman University
# 90                                                                      Undergraduate Research Assistant at Styczynski Lab
# 91                                                                            Lead Official at Western Illinois University
# 93                                                        Admissions Representative at Community medical center long beach
# 95                                                                                   Student at Westfield State University
# 96              Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint
# 11                                                                                           Student at Chapman University
# 98                                                                                                                 Student
# 5                                                                          Advisory Board Member at Celal Bayar University
# 4                                                                                   People Development Coordinator at Ryan
# 2                                                                Native English Teacher at EPIK (English Program in Korea)
# 102                                                                       Business Intelligence and Analytics at Travelers
# 16                                                               Native English Teacher at EPIK (English Program in Korea)
# 18                                                                                  People Development Coordinator at Ryan
# 20                                                               Native English Teacher at EPIK (English Program in Korea)
# 86                                    Information Systems Specialist and Programmer with a love for data and organization.
# 54                                                                                           Student at Chapman University
# 103                                                                                         Always set them up for Success
# 48                                                                         Advisory Board Member at Celal Bayar University
# 47                                                                                  People Development Coordinator at Ryan
# 45                                                               Native English Teacher at EPIK (English Program in Korea)
# 41                                                                                           Student at Chapman University
# 87                                                   Bachelor of Science in Biology from Victoria University of Wellington
# 35                                                                         Advisory Board Member at Celal Bayar University
# 32                                                               Native English Teacher at EPIK (English Program in Korea)
# 23                                                                         Advisory Board Member at Celal Bayar University
# 80                                                                                Junior MES Engineer| Information Systems
# 22                                                                                  People Development Coordinator at Ryan
# 59                                                                                  People Development Coordinator at Ryan
# 85                                                      RRP Brand Portfolio Executive at JTI (Japan Tobacco International)
# 34                                                                                  People Development Coordinator at Ryan
# 104                                                                       Director Of Administration at Excellence Logging
#
#                                 location connection     score  ranks
# id
# 28                     Chicago, Illinois        390  0.839155      1
# 30                     Chicago, Illinois        390  0.839155      1
# 99                Las Vegas, Nevada Area         48  0.833866      2
# 62             Greater Philadelphia Area      500+   0.614512      3
# 40             Greater Philadelphia Area      500+   0.614512      3
# 53             Greater Philadelphia Area      500+   0.614512      3
# 10             Greater Philadelphia Area      500+   0.614512      3
# 94           Amerika Birleşik Devletleri        415  0.542529      4
# 75                  San Jose, California      500+   0.501241      5
# 73                   Houston, Texas Area          7  0.198531      6
# 74                   Greater Boston Area         16  0.185727      7
# 27                   Houston, Texas Area      500+   0.154445      8
# 29                   Houston, Texas Area      500+   0.154445      8
# 33   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 97                  Kokomo, Indiana Area         71  0.151677      9
# 46   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 17   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 58   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 21   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 3    Raleigh-Durham, North Carolina Area         44  0.151677      9
# 60            Greater New York City Area          1  0.126410     10
# 6             Greater New York City Area          1  0.126410     10
# 36            Greater New York City Area          1  0.126410     10
# 24            Greater New York City Area          1  0.126410     10
# 49            Greater New York City Area          1  0.126410     10
# 100             Cape Girardeau, Missouri        103  0.123478     11
# 61                San Francisco Bay Area      500+   0.106629     12
# 38                San Francisco Bay Area      500+   0.106629     12
# 51                San Francisco Bay Area      500+   0.106629     12
# 8                 San Francisco Bay Area      500+   0.106629     12
# 26                San Francisco Bay Area      500+   0.106629     12
# 70              Virginia Beach, Virginia         82  0.092604     13
# 78           Amerika Birleşik Devletleri      500+   0.090110     14
# 101  Raleigh-Durham, North Carolina Area      500+   0.090110     14
# 68            Greater New York City Area      500+   0.087299     15
# 88                  Milpitas, California         18  0.086241     16
# 64                   Houston, Texas Area      500+   0.076558     17
# 55                   Houston, Texas Area      500+   0.076558     17
# 12                   Houston, Texas Area      500+   0.076558     17
# 42                   Houston, Texas Area      500+   0.076558     17
# 7                                 Kanada         61  0.075825     18
# 9                                 Kanada         61  0.075825     18
# 50                                Kanada         61  0.075825     18
# 25                                Kanada         61  0.075825     18
# 52                                Kanada         61  0.075825     18
# 39                                Kanada         61  0.075825     18
# 37                                Kanada         61  0.075825     18
# 71   Raleigh-Durham, North Carolina Area      500+   0.071788     19
# 13                      Atlanta, Georgia      500+   0.067282     20
# 43                      Atlanta, Georgia      500+   0.067282     20
# 65                      Atlanta, Georgia      500+   0.067282     20
# 56                      Atlanta, Georgia      500+   0.067282     20
# 67             Jackson, Mississippi Area      500+   0.065886     21
# 89                  Greater Atlanta Area        349  0.064570     22
# 92                  Torrance, California         64  0.061976     23
# 66                    Austin, Texas Area         57  0.061092     24
# 72                Monroe, Louisiana Area          5  0.061059     25
# 79           Baton Rouge, Louisiana Area          7  0.054438     26
# 84                  Highland, California         50  0.052919     27
# 82                    Austin, Texas Area        174  0.051878     28
# 83               Los Angeles, California        268  0.051501     29
# 1                         Houston, Texas         85  0.051296     30
# 57                        Houston, Texas         85  0.051296     30
# 19                        Houston, Texas         85  0.051296     30
# 15                        Houston, Texas         85  0.051296     30
# 44                        Houston, Texas         85  0.051296     30
# 31                        Houston, Texas         85  0.051296     30
# 14                        Houston, Texas         85  0.051296     30
# 69   Greater Grand Rapids, Michigan Area      500+   0.050441     31
# 81           Chattanooga, Tennessee Area        455  0.044019     32
# 76                    New York, New York        212  0.039992     33
# 77                Dallas/Fort Worth Area        409  0.038411     34
# 63               Lake Forest, California          2  0.000000     35
# 90                  Greater Atlanta Area        155  0.000000     35
# 91                  Greater Chicago Area         39  0.000000     35
# 93                Long Beach, California          9  0.000000     35
# 95            Bridgewater, Massachusetts         57  0.000000     35
# 96                    Lafayette, Indiana         19  0.000000     35
# 11               Lake Forest, California          2  0.000000     35
# 98                   Houston, Texas Area          4  0.000000     35
# 5                         İzmir, Türkiye      500+   0.000000     35
# 4                          Denton, Texas      500+   0.000000     35
# 2                                 Kanada      500+   0.000000     35
# 102           Greater New York City Area         49  0.000000     35
# 16                                Kanada      500+   0.000000     35
# 18                         Denton, Texas      500+   0.000000     35
# 20                                Kanada      500+   0.000000     35
# 86                Gaithersburg, Maryland          4  0.000000     35
# 54               Lake Forest, California          2  0.000000     35
# 103             Greater Los Angeles Area      500+   0.000000     35
# 48                        İzmir, Türkiye      500+   0.000000     35
# 47                         Denton, Texas      500+   0.000000     35
# 45                                Kanada      500+   0.000000     35
# 41               Lake Forest, California          2  0.000000     35
# 87                   Baltimore, Maryland         40  0.000000     35
# 35                        İzmir, Türkiye      500+   0.000000     35
# 32                                Kanada      500+   0.000000     35
# 23                        İzmir, Türkiye      500+   0.000000     35
# 80     Myrtle Beach, South Carolina Area         52  0.000000     35
# 22                         Denton, Texas      500+   0.000000     35
# 59                         Denton, Texas      500+   0.000000     35
# 85             Greater Philadelphia Area      500+   0.000000     35
# 34                         Denton, Texas      500+   0.000000     35
# 104                          Katy, Texas      500+   0.000000     35

# %% [markdown]
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">
# <b>Including job titles with scores greater than 0.10</p>

# %%
shr_top = shr.loc[shr['score']>0.10]
shr_top
# Out:
#                                                                                                                  job_title  \
# id
# 28                                                                                   Seeking Human Resources Opportunities
# 30                                                                                   Seeking Human Resources Opportunities
# 99                                                                                        Seeking Human Resources Position
# 62                                                                   Seeking Human Resources HRIS and Generalist Positions
# 40                                                                   Seeking Human Resources HRIS and Generalist Positions
# 53                                                                   Seeking Human Resources HRIS and Generalist Positions
# 10                                                                   Seeking Human Resources HRIS and Generalist Positions
# 94                                                  Seeking Human  Resources Opportunities. Open to travel and relocation.
# 75                    Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621
# 73                                                Aspiring Human Resources Manager, seeking internship in Human Resources.
# 74                                                                                            Human Resources Professional
# 27                                                       Aspiring Human Resources Management student seeking an internship
# 29                                                       Aspiring Human Resources Management student seeking an internship
# 33                                                                                   Aspiring Human Resources Professional
# 97                                                                                   Aspiring Human Resources Professional
# 46                                                                                   Aspiring Human Resources Professional
# 17                                                                                   Aspiring Human Resources Professional
# 58                                                                                   Aspiring Human Resources Professional
# 21                                                                                   Aspiring Human Resources Professional
# 3                                                                                    Aspiring Human Resources Professional
# 60                                                                                     Aspiring Human Resources Specialist
# 6                                                                                      Aspiring Human Resources Specialist
# 36                                                                                     Aspiring Human Resources Specialist
# 24                                                                                     Aspiring Human Resources Specialist
# 49                                                                                     Aspiring Human Resources Specialist
# 100  Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis
# 61                                                                                                    HR Senior Specialist
# 38                                                                                                    HR Senior Specialist
# 51                                                                                                    HR Senior Specialist
# 8                                                                                                     HR Senior Specialist
# 26                                                                                                    HR Senior Specialist
#
#                                 location connection     score  ranks
# id
# 28                     Chicago, Illinois        390  0.839155      1
# 30                     Chicago, Illinois        390  0.839155      1
# 99                Las Vegas, Nevada Area         48  0.833866      2
# 62             Greater Philadelphia Area      500+   0.614512      3
# 40             Greater Philadelphia Area      500+   0.614512      3
# 53             Greater Philadelphia Area      500+   0.614512      3
# 10             Greater Philadelphia Area      500+   0.614512      3
# 94           Amerika Birleşik Devletleri        415  0.542529      4
# 75                  San Jose, California      500+   0.501241      5
# 73                   Houston, Texas Area          7  0.198531      6
# 74                   Greater Boston Area         16  0.185727      7
# 27                   Houston, Texas Area      500+   0.154445      8
# 29                   Houston, Texas Area      500+   0.154445      8
# 33   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 97                  Kokomo, Indiana Area         71  0.151677      9
# 46   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 17   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 58   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 21   Raleigh-Durham, North Carolina Area         44  0.151677      9
# 3    Raleigh-Durham, North Carolina Area         44  0.151677      9
# 60            Greater New York City Area          1  0.126410     10
# 6             Greater New York City Area          1  0.126410     10
# 36            Greater New York City Area          1  0.126410     10
# 24            Greater New York City Area          1  0.126410     10
# 49            Greater New York City Area          1  0.126410     10
# 100             Cape Girardeau, Missouri        103  0.123478     11
# 61                San Francisco Bay Area      500+   0.106629     12
# 38                San Francisco Bay Area      500+   0.106629     12
# 51                San Francisco Bay Area      500+   0.106629     12
# 8                 San Francisco Bay Area      500+   0.106629     12
# 26                San Francisco Bay Area      500+   0.106629     12

# %% [markdown]
# <a name="Keyword based search: Aspiring Human Resources"></a>
# <b>ii) Keyword based search: Aspiring Human Resources</b>

# %%
# Getting ranks for Aspiring human resources
ahr = keyword_ranking(
    text=text_prep,
    ngram_range=(1, 3),
    boost=0.2
)
ahr
# Out:
# Enter a keyword: Aspiring Human Reources
#                                                                                                                  job_title  \
# id
# 97                                                                                   Aspiring Human Resources Professional
# 3                                                                                    Aspiring Human Resources Professional
# 33                                                                                   Aspiring Human Resources Professional
# 21                                                                                   Aspiring Human Resources Professional
# 58                                                                                   Aspiring Human Resources Professional
# 46                                                                                   Aspiring Human Resources Professional
# 17                                                                                   Aspiring Human Resources Professional
# 6                                                                                      Aspiring Human Resources Specialist
# 24                                                                                     Aspiring Human Resources Specialist
# 36                                                                                     Aspiring Human Resources Specialist
# 60                                                                                     Aspiring Human Resources Specialist
# 49                                                                                     Aspiring Human Resources Specialist
# 52                                                       Student at Humber College and Aspiring Human Resources Generalist
# 25                                                       Student at Humber College and Aspiring Human Resources Generalist
# 37                                                       Student at Humber College and Aspiring Human Resources Generalist
# 39                                                       Student at Humber College and Aspiring Human Resources Generalist
# 50                                                       Student at Humber College and Aspiring Human Resources Generalist
# 9                                                        Student at Humber College and Aspiring Human Resources Generalist
# 7                                                        Student at Humber College and Aspiring Human Resources Generalist
# 73                                                Aspiring Human Resources Manager, seeking internship in Human Resources.
# 27                                                       Aspiring Human Resources Management student seeking an internship
# 29                                                       Aspiring Human Resources Management student seeking an internship
# 66                                                    Experienced Retail Manager and aspiring Human Resources Professional
# 72                                                          Business Management Major and Aspiring Human Resources Manager
# 79                                                                   Liberal Arts Major. Aspiring Human Resources Analyst.
# 82                                            Aspiring Human Resources Professional | An energetic and Team-Focused Leader
# 57                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 44                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 31                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 14                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 15                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 19                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 100  Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis
# 76   Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment
# 74                                                                                            Human Resources Professional
# 10                                                                   Seeking Human Resources HRIS and Generalist Positions
# 62                                                                   Seeking Human Resources HRIS and Generalist Positions
# 53                                                                   Seeking Human Resources HRIS and Generalist Positions
# 40                                                                   Seeking Human Resources HRIS and Generalist Positions
# 51                                                                                                    HR Senior Specialist
# 8                                                                                                     HR Senior Specialist
# 61                                                                                                    HR Senior Specialist
# 38                                                                                                    HR Senior Specialist
# 26                                                                                                    HR Senior Specialist
# 28                                                                                   Seeking Human Resources Opportunities
# 30                                                                                   Seeking Human Resources Opportunities
# 99                                                                                        Seeking Human Resources Position
# 101                                                                                  Human Resources Generalist at Loparex
# 78                                                                                  Human Resources Generalist at Schwan's
# 68                                                                                 Human Resources Specialist at Luxottica
# 88                                                                                        Human Resources Management Major
# 55             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 42             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 12             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 64             SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 71                                                                         Human Resources Generalist at ScottMadden, Inc.
# 43                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 56                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 13                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 65                                                        Human Resources Coordinator at InterContinental Buckhead Atlanta
# 67                                                                   Human Resources, Staffing and Recruiting Professional
# 89                                                                                         Director Human Resources  at EY
# 94                                                  Seeking Human  Resources Opportunities. Open to travel and relocation.
# 84                                                       Human Resources professional for the world leader in GIS software
# 83                                                                               HR Manager at Endemol Shine North America
# 69                                                              Director of Human Resources North America, Groupe Beneteau
# 75                    Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621
# 81                                                           Senior Human Resources Business Partner at Heil Environmental
# 77                 Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation
# 70                          Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.
# 35                                                                         Advisory Board Member at Celal Bayar University
# 23                                                                         Advisory Board Member at Celal Bayar University
# 102                                                                       Business Intelligence and Analytics at Travelers
# 90                                                                      Undergraduate Research Assistant at Styczynski Lab
# 91                                                                            Lead Official at Western Illinois University
# 92                                                Seeking employment opportunities within Customer Service or Patient Care
# 93                                                        Admissions Representative at Community medical center long beach
# 32                                                               Native English Teacher at EPIK (English Program in Korea)
# 95                                                                                   Student at Westfield State University
# 96              Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint
# 2                                                                Native English Teacher at EPIK (English Program in Korea)
# 98                                                                                                                 Student
# 34                                                                                  People Development Coordinator at Ryan
# 87                                                   Bachelor of Science in Biology from Victoria University of Wellington
# 63                                                                                           Student at Chapman University
# 85                                                      RRP Brand Portfolio Executive at JTI (Japan Tobacco International)
# 54                                                                                           Student at Chapman University
# 103                                                                                         Always set them up for Success
# 11                                                                                           Student at Chapman University
# 16                                                               Native English Teacher at EPIK (English Program in Korea)
# 48                                                                         Advisory Board Member at Celal Bayar University
# 47                                                                                  People Development Coordinator at Ryan
# 18                                                                                  People Development Coordinator at Ryan
# 45                                                               Native English Teacher at EPIK (English Program in Korea)
# 41                                                                                           Student at Chapman University
# 20                                                               Native English Teacher at EPIK (English Program in Korea)
# 22                                                                                  People Development Coordinator at Ryan
# 5                                                                          Advisory Board Member at Celal Bayar University
# 80                                                                                Junior MES Engineer| Information Systems
# 4                                                                                   People Development Coordinator at Ryan
# 59                                                                                  People Development Coordinator at Ryan
# 86                                    Information Systems Specialist and Programmer with a love for data and organization.
# 104                                                                       Director Of Administration at Excellence Logging
#
#                                 location connection     score  ranks
# id
# 97                  Kokomo, Indiana Area         71  0.520733      1
# 3    Raleigh-Durham, North Carolina Area         44  0.520733      1
# 33   Raleigh-Durham, North Carolina Area         44  0.520733      1
# 21   Raleigh-Durham, North Carolina Area         44  0.520733      1
# 58   Raleigh-Durham, North Carolina Area         44  0.520733      1
# 46   Raleigh-Durham, North Carolina Area         44  0.520733      1
# 17   Raleigh-Durham, North Carolina Area         44  0.520733      1
# 6             Greater New York City Area          1  0.433985      2
# 24            Greater New York City Area          1  0.433985      2
# 36            Greater New York City Area          1  0.433985      2
# 60            Greater New York City Area          1  0.433985      2
# 49            Greater New York City Area          1  0.433985      2
# 52                                Kanada         61  0.260319      3
# 25                                Kanada         61  0.260319      3
# 37                                Kanada         61  0.260319      3
# 39                                Kanada         61  0.260319      3
# 50                                Kanada         61  0.260319      3
# 9                                 Kanada         61  0.260319      3
# 7                                 Kanada         61  0.260319      3
# 73                   Houston, Texas Area          7  0.232755      4
# 27                   Houston, Texas Area      500+   0.215640      5
# 29                   Houston, Texas Area      500+   0.215640      5
# 66                    Austin, Texas Area         57  0.209740      6
# 72                Monroe, Louisiana Area          5  0.209625      7
# 79           Baton Rouge, Louisiana Area          7  0.186896      8
# 82                    Austin, Texas Area        174  0.178106      9
# 57                        Houston, Texas         85  0.176107     10
# 44                        Houston, Texas         85  0.176107     10
# 31                        Houston, Texas         85  0.176107     10
# 1                         Houston, Texas         85  0.176107     10
# 14                        Houston, Texas         85  0.176107     10
# 15                        Houston, Texas         85  0.176107     10
# 19                        Houston, Texas         85  0.176107     10
# 100             Cape Girardeau, Missouri        103  0.144764     11
# 76                    New York, New York        212  0.137301     12
# 74                   Greater Boston Area         16  0.115521     13
# 10             Greater Philadelphia Area      500+   0.069624     14
# 62             Greater Philadelphia Area      500+   0.069624     14
# 53             Greater Philadelphia Area      500+   0.069624     14
# 40             Greater Philadelphia Area      500+   0.069624     14
# 51                San Francisco Bay Area      500+   0.066322     15
# 8                 San Francisco Bay Area      500+   0.066322     15
# 61                San Francisco Bay Area      500+   0.066322     15
# 38                San Francisco Bay Area      500+   0.066322     15
# 26                San Francisco Bay Area      500+   0.066322     15
# 28                     Chicago, Illinois        390  0.062057     16
# 30                     Chicago, Illinois        390  0.062057     16
# 99                Las Vegas, Nevada Area         48  0.061543     17
# 101  Raleigh-Durham, North Carolina Area      500+   0.056048     18
# 78           Amerika Birleşik Devletleri      500+   0.056048     18
# 68            Greater New York City Area      500+   0.054299     19
# 88                  Milpitas, California         18  0.053641     20
# 55                   Houston, Texas Area      500+   0.047619     21
# 42                   Houston, Texas Area      500+   0.047619     21
# 12                   Houston, Texas Area      500+   0.047619     21
# 64                   Houston, Texas Area      500+   0.047619     21
# 71   Raleigh-Durham, North Carolina Area      500+   0.044652     22
# 43                      Atlanta, Georgia      500+   0.041849     23
# 56                      Atlanta, Georgia      500+   0.041849     23
# 13                      Atlanta, Georgia      500+   0.041849     23
# 65                      Atlanta, Georgia      500+   0.041849     23
# 67             Jackson, Mississippi Area      500+   0.040981     24
# 89                  Greater Atlanta Area        349  0.040162     25
# 94           Amerika Birleşik Devletleri        415  0.033257     26
# 84                  Highland, California         50  0.032915     27
# 83               Los Angeles, California        268  0.032033     28
# 69   Greater Grand Rapids, Michigan Area      500+   0.031374     29
# 75                  San Jose, California      500+   0.029248     30
# 81           Chattanooga, Tennessee Area        455  0.027380     31
# 77                Dallas/Fort Worth Area        409  0.023891     32
# 70              Virginia Beach, Virginia         82  0.023425     33
# 35                        İzmir, Türkiye      500+   0.000000     34
# 23                        İzmir, Türkiye      500+   0.000000     34
# 102           Greater New York City Area         49  0.000000     34
# 90                  Greater Atlanta Area        155  0.000000     34
# 91                  Greater Chicago Area         39  0.000000     34
# 92                  Torrance, California         64  0.000000     34
# 93                Long Beach, California          9  0.000000     34
# 32                                Kanada      500+   0.000000     34
# 95            Bridgewater, Massachusetts         57  0.000000     34
# 96                    Lafayette, Indiana         19  0.000000     34
# 2                                 Kanada      500+   0.000000     34
# 98                   Houston, Texas Area          4  0.000000     34
# 34                         Denton, Texas      500+   0.000000     34
# 87                   Baltimore, Maryland         40  0.000000     34
# 63               Lake Forest, California          2  0.000000     34
# 85             Greater Philadelphia Area      500+   0.000000     34
# 54               Lake Forest, California          2  0.000000     34
# 103             Greater Los Angeles Area      500+   0.000000     34
# 11               Lake Forest, California          2  0.000000     34
# 16                                Kanada      500+   0.000000     34
# 48                        İzmir, Türkiye      500+   0.000000     34
# 47                         Denton, Texas      500+   0.000000     34
# 18                         Denton, Texas      500+   0.000000     34
# 45                                Kanada      500+   0.000000     34
# 41               Lake Forest, California          2  0.000000     34
# 20                                Kanada      500+   0.000000     34
# 22                         Denton, Texas      500+   0.000000     34
# 5                         İzmir, Türkiye      500+   0.000000     34
# 80     Myrtle Beach, South Carolina Area         52  0.000000     34
# 4                          Denton, Texas      500+   0.000000     34
# 59                         Denton, Texas      500+   0.000000     34
# 86                Gaithersburg, Maryland          4  0.000000     34
# 104                          Katy, Texas      500+   0.000000     34

# %% [markdown]
# <a name="Keyword based search: Research Assistant"></a>
# <b>iii) Keyword based search: Research Assistant</b>

# %%
# Getting ranks for Research Assistant
resass = keyword_ranking(
    text=text_prep,
    ngram_range=(1, 2),
    boost=0.2
)
resass.head(20)
# Out:
# Enter a keyword: Research Assistant
#                                                                                                                 job_title  \
# id
# 90                                                                     Undergraduate Research Assistant at Styczynski Lab
# 1                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 75                   Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621
# 74                                                                                           Human Resources Professional
# 73                                               Aspiring Human Resources Manager, seeking internship in Human Resources.
# 72                                                         Business Management Major and Aspiring Human Resources Manager
# 71                                                                        Human Resources Generalist at ScottMadden, Inc.
# 70                         Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.
# 69                                                             Director of Human Resources North America, Groupe Beneteau
# 68                                                                                Human Resources Specialist at Luxottica
# 67                                                                  Human Resources, Staffing and Recruiting Professional
# 76  Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment
# 66                                                   Experienced Retail Manager and aspiring Human Resources Professional
# 64            SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 63                                                                                          Student at Chapman University
# 62                                                                  Seeking Human Resources HRIS and Generalist Positions
# 61                                                                                                   HR Senior Specialist
# 60                                                                                    Aspiring Human Resources Specialist
# 59                                                                                 People Development Coordinator at Ryan
# 58                                                                                  Aspiring Human Resources Professional
#
#                                location connection    score  ranks
# id
# 90                 Greater Atlanta Area        155  0.77735      1
# 1                        Houston, Texas         85  0.00000      2
# 75                 San Jose, California      500+   0.00000      2
# 74                  Greater Boston Area         16  0.00000      2
# 73                  Houston, Texas Area          7  0.00000      2
# 72               Monroe, Louisiana Area          5  0.00000      2
# 71  Raleigh-Durham, North Carolina Area      500+   0.00000      2
# 70             Virginia Beach, Virginia         82  0.00000      2
# 69  Greater Grand Rapids, Michigan Area      500+   0.00000      2
# 68           Greater New York City Area      500+   0.00000      2
# 67            Jackson, Mississippi Area      500+   0.00000      2
# 76                   New York, New York        212  0.00000      2
# 66                   Austin, Texas Area         57  0.00000      2
# 64                  Houston, Texas Area      500+   0.00000      2
# 63              Lake Forest, California          2  0.00000      2
# 62            Greater Philadelphia Area      500+   0.00000      2
# 61               San Francisco Bay Area      500+   0.00000      2
# 60           Greater New York City Area          1  0.00000      2
# 59                        Denton, Texas      500+   0.00000      2
# 58  Raleigh-Durham, North Carolina Area         44  0.00000      2

# %% [markdown]
# <a name="Final Notes"></a>
# #### <b>Final Notes</b>

# %% [markdown]
# <p style="font-size:14px; line-height:1.5; margin-top:0px; margin-bottom:4px;">
# <ul>
# <li> The <b>TF-DFI model</b> with Exact Match keyword Rank-based produced better rankings because it matches keywords literally, such as <i>"seeking human resources"</i> and <i>"aspiring human resources".</i></li>
# <br>
# <li> Results can be filtered by defining a <b>score threshold,</b> which might vary depending on the keywords. Keep it wider (>10) when the job title is common within the dataset, or on the contrary, tighten the threshold when the search is for an uncommon title (e.g., research assistant).</li>
# <br>
# <li> Given that keyword-based rankings might suffer from any type of <b>bias (vocabulary, synonym, or spelling)</b>. A mitigation technique should be implemented, like fuzzy matching, which is useful to find partial string matches. </li>
# <br>
# <li> Lastly, I tried two <b>Neural Approaches:</b> Continuous Bag of Words (CBOW) and Skip-Gram Models. However, none of these models improve the final score because the essence of this technique is based on semantic similarity, instead of an exact match. Therefore, additional words in a sentence can dilute or reinforce the meaning when ranking for keywords.</li>
# </ul>
# </p>
